# %% [markdown]
# Testing my All Codes one by one

# %%
import sys
sys.path.append(r"C:\Users\piyush kirola\Documents\codes_50")

from all_programs import AllPrograms

obj = AllPrograms()

# %%
methods = [
    obj.prime_checker,
    obj.reverse,
    obj.palindrome,
    obj.factorial,
    obj.second_largest_number,
    obj.anagram,
    obj.count_vowels,
    obj.sum_digits,
    obj.fibonacci_sequence,
    obj.remove_duplicate,
    obj.check_leap_year,
    obj.power,
    obj.even_numbers,
    obj.reverse_words,
    obj.gcd_recursive,
    obj.decimal_to_binary,
    obj.factorial_recursion,
    obj.largest_number,
    obj.count,
    obj.intersection_list,
    obj.whitespace,
    obj.sum_list,
    obj.is_prime_numbers,
    obj.merge_sorted_list,
    obj.sorted_list,
    obj.frequency_word,
    obj.missing_consecutive_num,
    obj.sum_squares,
    obj.rev_int,
    obj.longest_word,
    obj.num_power,
    obj.flatten,
    obj.find_pairs,
    obj.rotation_checker,
    obj.tuple_dict,
    obj.median,
    obj.sorted_dict,
    obj.list_prime_numbers,
    obj.binary_to_decimal,
    obj.subsequence_list,
    obj.common_elements_list,
    obj.swapping_numbers,
    obj.remove_oucuurence,
    obj.first_non_repeated_character,
    obj.digits_checks,
    obj.armstrong_number_check,
    obj.generate_subsets
]

for m in methods:
    print(f"Running: {m.__name__}")
    try:
        m()
    except Exception as e:
        print(f"Error in {m.__name__}: {e}")
    print("-" * 40)
# Out:
# Running: prime_checker
# Enter the number :  29
# 29 is a prime number
# ----------------------------------------
# Running: reverse
# Enter any string :  python
# The reverse of python is : nohtyp
# ----------------------------------------
# Running: palindrome
# Enter any string :  madam
# The reverse of madam is : madam
# This string is Palindrome
# ----------------------------------------
# Running: factorial
# Enter any number : 5
# The Factorial of 5 is : 120
# ----------------------------------------
# Running: second_largest_number
# The list is: [12, 45, 7, 89, 23, 67, 90, 34]
# The second largest element is: 89
# ----------------------------------------
# Running: anagram
# Enter First string : listen
# Enter Second string : silent
# They are Anagram
# ----------------------------------------
# Running: count_vowels
# Enter any string : hello this is python
# The Total vowels count in hello this is python is : 5
# ----------------------------------------
# ...
